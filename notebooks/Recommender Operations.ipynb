# %% [markdown]
# # Recommendation Operations
#
# This Notebook contains interfaces that are needed to recommend projects to a user for the Web Demonstrator

# %%
import sys
import os
if os.path.abspath("..") not in sys.path:
    sys.path.append(os.path.abspath('..'))
from data import aws

# %% [markdown]
# # Show Mapping: User to Images

# %%
aws.get_user_goal()
# Out:
#    user_id            image
# 0        1          1,3,4,6
# 1        2        1,2,3,4,5
# 2        3  1,2,3,4,5,6,7,8
# 3       16            1,2,3
# 4       19            1,2,3

# %% [markdown]
# # Pick a User from List

# %%
user_id = 19

# %% [markdown]
# # Show Projects for User

# %%
aws.get_projects(user_id)
# Out:
#                                              NGO_NAME  \
# 0                              Off Road Kids Stiftung
# 1                               Berliner Stadtmission
# 2            Frankfurter Arbeitsloseninitiative e. V.
# 3   Verein für soziale Arbeit im Stadtteil Bockenheim
# 4                                  StrassenBLUES e.V.
# 5                             Westwind Hamburg e.V. |
# 6                                 Hanseatic Help e.V.
# 7                                 Hanseatic Help e.V.
# 8                                  StrassenBLUES e.V.
# 9                                UNTER EINEM DACH gUG
# 10       Lebensbrücke International Deutschland gGmbH
# 11                         Stadtmission Nürnberg e.V.
# 12                                   Aufwind-Mannheim
# 13                         NABU Gruppe Stuttgart e. V
# 14  POEMA e.V. Stuttgart-Armut und Umwelt in Amazo...
# 15    Caritasverband der Diözese Rottenburg-Stuttgart
# ...

# %% [markdown]
# # Show Mapping : Images to Goals

# %%
aws.get_image_goal()
# Out:
#     image_id             goal
# 0          1          1,3,4,6
# 1          2        1,2,3,4,5
# 2          3  1,2,3,4,5,6,7,8
# 3          4            11,17
# 4          5            6,7,8
# 5          6               10
# 6          7                9
# 7          8                8
# 8          9                5
# 9         10          4,6,7,9
# 10        11                1
# 11        12               12
# 12        13               13
# 13        14               14
# 14        15               15
# 15        16            1,2,3
# 16        17               16
# 17        18               17
# 18        19            1,2,3
# 19        20        3,4,5,6,7
# 20        21       6,7,8,9,10

# %% [markdown]
# # Show Mapping : Goals to Projects

# %%
aws.get_goal_project()
# Out:
#     project_id  goal    weight
# 0        22744     1  0.571429
# 1        49352     8  0.571429
# 2        79880     2  0.571429
# 3        36236    10  0.571429
# 4        34094     3  0.571429
# ..         ...   ...       ...
# 233      59962    13  0.142857
# 234      40502    13  0.142857
# 235      80975     8  0.142857
# 236      82404     6  0.142857
# 237      48952     3  0.142857
#
# [238 rows x 3 columns]

# %% [markdown]
# # Show Raw Labeled Data

# %%
aws.get_labels()
# Out:
#      LABEL_ID  DATA_SOURCE    CITY  PROJECT_ID  \
# 0           0            0    City  Project ID
# 1           1            0  BERLIN       22744
# 2           2            0               49352
# 3           3            0               79880
# 4           4            0               36236
# ..        ...          ...     ...         ...
# 196       196            0               43625
# 197       197            0               24133
# 198       198            0               54424
# 199       199            0               35454
# 200       200            0               70849
#
#                                      NGO_NAME  \
# 0                             Betterplace NGO
# 1                      Off Road Kids Stiftung
# 2                               jobs4refugees
# 3                      Tafel Deutschland e.V.
# 4                     Start with a Friend e.V
# ..                                        ...
# 196                                BILING e.V
# ...
